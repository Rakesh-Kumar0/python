# %% [markdown]
# # not recommended

# %%
answer1 = input("write the item you want to buy :")
answer2 = input("write the fruit you want to buy :")

if answer1 == "fruit":
    if answer2 == "apple":
        print("Task completed")
    else :
        print("Task not completed")
else :
    print("Item not available")
# Out:
# Task not completed

# %% [markdown]
# # Recommended

# %%
amswer1 = input("write the item you want to buy :")

if answer1 == "fruit":
    answer2 = input("write the fruit you want to buy :")
    if answer2 == "apple" :
        print("Task completed")
    else :
        print("Task not completed")
else :
    print("Item not available.")
# Out:
# Task not completed

# %% [markdown]
# # Advanced data type

# %%
name1 = "abc"
mobile_no1 = "9876543234"

name2 = "abc"
mobile_no2 = "9876543234"

# %% [markdown]
# ## list

# %%
names = [] # name = list()

# %%
print(names)
# Out:
# []

# %%
#.append() -> it will insert the value in exicting list

names.append("abc")

# %%
print(names)
# Out:
# ['abc']

# %%
a = [0,1,2,4,"rakesh", "ashar", "heartine", "enjoy", "nikhil"]

# %%
len(a) # total number of elements
# Out:
# 9

# %%
a[0]
# Out:
# 0

# %%
a[4]
# Out:
# 'rakesh'

# %%
a[-1]
# Out:
# 'nikhil'

# %%
a[0:6] # list sclising
# Out:
# [0, 1, 2, 4, 'rakesh', 'ashar']

# %%
a[5:6]
# Out:
# ['ashar']

# %%
a[-1:-3] # not give error
# Out:
# []

# %%
a[-3:-1]
# Out:
# ['heartine', 'enjoy']

# %%
a[-7:-1]
# Out:
# [2, 4, 'rakesh', 'ashar', 'heartine', 'enjoy']

# %%
a[-7:]
# Out:
# [2, 4, 'rakesh', 'ashar', 'heartine', 'enjoy', 'nikhil']

# %%
a[0:]
# Out:
# [0, 1, 2, 4, 'rakesh', 'ashar', 'heartine', 'enjoy', 'nikhil']

# %%
a[0:-1]
# Out:
# [0, 1, 2, 4, 'rakesh', 'ashar', 'heartine', 'enjoy']

# %%
a[0:len(a)]
# Out:
# [0, 1, 2, 4, 'rakesh', 'ashar', 'heartine', 'enjoy', 'nikhil']

# %%
a[:]
# Out:
# [0, 1, 2, 4, 'rakesh', 'ashar', 'heartine', 'enjoy', 'nikhil']

# %%
names = []
places = []

# %%
name = input("Enter name : ")
place = input("Enter place: ")

names.append(name)
places.append(place)

# %%
print(names)
print(places)
# Out:
# ['Rakesh', 'Ram']
# ['Sursand', 'kohla']

# %%
i = int(input("Enter the user id to the patient info :"))
print(names[i])
print(places[i])
# Out:
# Rakesh
# Sursand

# %%
names['1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 names['1']
#
# TypeError: list indices must be integers or slices, not str

# %%
a = []

# %%
val = 1

# %%
a.append(val) # the number of times you run this cell it will append that number od time in a list

# %%
print(a)
# Out:
# [1, 1, 1, 1, 1, [1, 2]]

# %%
a.append([1,2])

# %%
print(a)
# Out:
# [1, 1, 1, 1, 1, [1, 2], [1, 2]]

# %%
len(a)
# Out:
# 7

# %%
a[2]
# Out:
# 1

# %%
a[3]
# Out:
# 1

# %%
a[5][1]
# Out:
# 2

# %%
a = int(input("Enter details"))
print(type(a))
# Out:
# <class 'int'>

# %%
a = list(input("Enter details"))
print(type(a))
# Out:
# <class 'list'>

# %%
print(a)
# Out:
# ['[', '1', ',', '2', ',', '3', ',', '4', '[', '4', ',', '5', ']', ']']
