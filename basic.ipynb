# %% [markdown]
# # Topic: Basic of python

# %% [markdown]
# ## To run cell: Shift+Enter

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(1+2)
# Out:
# 3

# %%
number1 = 5
number2 = 6
print(number1 + number2)
# Out:
# 11

# %%
# type is used to print type of variable
type(number1)
# Out:
# int

# %%
first_name = "Rakesh"
last_name = "kumar"
type(first_name)
# Out:
# str

# %%
# typecasting
float(number1)
# Out:
# 5.0

# %%
str(number2)
# Out:
# '6'

# %%
float(first_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 float(first_name)
#
# ValueError: could not convert string to float: 'Rakesh'

# %%
# taking input
name = input("Enter your name")
print(name)
# Out:
# rakesh kumar

# %%
### Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 9.0
# Difference: 1.0
# Product: 20.0
# Quotient: 1.25
