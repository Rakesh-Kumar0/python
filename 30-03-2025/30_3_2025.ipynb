# %%
a = 4
b = 2

# %%
print(a+b)
print(type(a+b))
# Out:
# 6
# <class 'int'>

# %%
print(a/b)
print(type(a/b))
# Out:
# 2.0
# <class 'float'>

# %%
print(a*b)
print(type(a*b))
# Out:
# 8
# <class 'int'>

# %%
print(a**b)
print(type(a**b))
# Out:
# 16
# <class 'int'>

# %%
print(4**2.2)
print(type(4**2.2))
# Out:
# 21.112126572366314
# <class 'float'>

# %%
print(a-b)
print(type(a-b))
# Out:
# 2
# <class 'int'>

# %%
print(a//b)
print(type(a//b))
# Out:
# 2
# <class 'int'>

# %%
print(a%b)
print(type(a%b))
# Out:
# 0
# <class 'int'>

# %%
name = "rakesh"
print(name)
# Out:
# rakesh

# %%
name = "rakesh                     "
print(name)
# Out:
# rakesh

# %%
name = name.rstrip()
print(name)
# Out:
# rakesh

# %%
name = "         rakesh"
print(name)
# Out:
#          rakesh

# %%
name = name.lstrip()
print(name)
# Out:
# rakesh

# %%
name = "       rakesh      "
print(name)
# Out:
#        rakesh

# %%
name = name.strip()
print(name)
# Out:
# rakesh

# %%
a = 2
b = 2
print(a==b)
# Out:
# True
